# %%
import pandas as pd

# %%
data = pd.read_csv('gene_high_throughput_sequencing.csv')

# %%
data.head()
# Out:
#                   Patient_id Diagnosis  LOC643837  LOC100130417     SAMD11  \
# 0  STT5425_Breast_001_normal    normal   1.257614      2.408148  13.368622
# 1  STT5427_Breast_023_normal    normal   4.567931     16.602734  42.477752
# 2  STT5430_Breast_002_normal    normal   2.077597      3.978294  12.863214
# 3  STT5439_Breast_003_normal    normal   2.066576      8.520713  14.466035
# 4  STT5441_Breast_004_normal    normal   2.613616      3.434965  12.682222
#
#        NOC2L     KLHL17    PLEKHN1   C1orf170       HES4  ...      CLIC2  \
# 0   9.494779  20.880435  12.722017   9.494779  54.349694  ...   4.761250
# 1  25.562376  23.221137  11.622386  14.330573  72.445474  ...   6.871902
# 2  13.728915  14.543176  14.141907   6.232790  57.011005  ...   7.096343
# 3   7.823932   8.520713   2.066576  10.870009  53.292034  ...   5.200770
# 4  10.543189  26.688686  12.484822   1.364917  67.140393  ...  11.227770
#
#      RPS4Y1       ZFY      PRKY     USP9Y     DDX3Y       CD24  CYorf15B  \
# ...

# %%
data_norm = data.loc[data['Diagnosis'] == 'normal']
data_early = data.loc[data['Diagnosis'] == 'early neoplasia']
data_cancer = data.loc[data['Diagnosis'] == 'cancer']

# %%
data_norm.drop(['Patient_id', 'Diagnosis'], axis='columns')
data_norm
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 data_norm.drop(['Patient_id', 'Diagnosis'], axis='columns')
#       2 data_norm
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
data_early.drop(['Patient_id', 'Diagnosis'], axis='columns', inplace=True)
data_early
# Out:
# C:\Users\maaga\AppData\Local\Temp\ipykernel_8796\3404964647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_early.drop(['Patient_id', 'Diagnosis'], axis='columns', inplace=True)
#     LOC643837  LOC100130417     SAMD11      NOC2L     KLHL17    PLEKHN1  \
# 24   2.516305     11.430887  18.506550  13.969049  20.957007  10.374992
# 25   1.937270      9.686352  23.541357  15.295034  18.815807  11.128772
# 26   1.405858     15.119783  17.985461  17.237294  21.824785   4.801919
# 27   2.131757      8.789458  12.731187   6.395270  19.185811  14.922297
# 28   2.421766      7.830416  18.283935  15.229320  29.234970  15.779540
# 29   4.668232     14.949208  27.070696  19.599600  34.110743  13.633645
# 30   3.386331     12.379176  28.350470  14.547256  22.989898  14.257730
# ...

# %%
data_cancer.drop(['Patient_id', 'Diagnosis'], axis='columns', inplace=True)
data_cancer
# Out:
# C:\Users\maaga\AppData\Local\Temp\ipykernel_8796\3946831174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cancer.drop(['Patient_id', 'Diagnosis'], axis='columns', inplace=True)
#     LOC643837  LOC100130417     SAMD11      NOC2L     KLHL17    PLEKHN1  \
# 49   1.618129      4.854387   7.646980  11.631036  19.839961  19.484855
# 50   1.609022     10.632542  28.344988  18.462903  23.702379  13.494061
# 51   1.549953      3.900629  12.496120  10.242207  22.972095  16.860563
# 52   1.606786      4.043656   8.849487  15.158388  26.287855  27.441093
# 53   2.697819      8.225604  21.299676  14.114099  22.289155  14.341455
# 54   1.126738      4.996760  13.442388  11.691325  21.169493   8.703401
# 55   3.163299     11.208777  25.033996  14.749504  28.573643  18.891720
# ...

# %%
import scipy.stats as stats

# %%
ttest_ind = stats.ttest_ind (data_norm, data_early)
ttest_1samp = stats.ttest_1samp (data_norm, data_early)
ttest_ind
# Out:
# Ttest_indResult(statistic=array([ 0.4005076 , -4.59402085, -1.93950722, ..., -0.42476287,
#        -0.26069036, -0.43902942]), pvalue=array([6.90597471e-01, 3.27055165e-05, 5.84549088e-02, ...,
#        6.72947839e-01, 7.95470130e-01, 6.62652020e-01]))

# %%
ttest_1samp
# Out:
# Ttest_1sampResult(statistic=    LOC643837  LOC100130417     SAMD11     NOC2L     KLHL17    PLEKHN1  \
# 24   0.535765    -11.361008  -2.400716  1.358297   0.560406  -1.429395
# 25   2.416247     -8.554639  -6.012069  0.076664   2.946548  -2.506352
# 26   4.142069    -17.295200  -2.026950 -1.800632  -0.406641   6.533102
# 27   1.784630     -7.111838   1.741821  8.678749   2.534218  -7.926331
# 28   0.842791     -5.569061  -2.241039  0.140179  -8.664515  -9.151111
# 29  -6.452862    -17.020803  -8.543584 -4.083923 -14.098052  -6.085176
# 30  -2.289742    -12.886486  -9.461537  0.799430  -1.705038  -6.976833
# 31   4.656550      0.173219   2.689286  6.193483   5.560016   6.045318
# 32   3.538372     -6.441012   1.298546  5.334613   1.407344  -2.953025
# 33   5.528098      1.064585  -1.812642  2.557870  -5.544246  -7.464171
# 34  -6.655532    -19.448897  -6.373562  4.335119  -7.551656 -10.005038
# 35   5.574336     -3.228937   2.165438  5.550017  10.159393   4.858952
# ...
